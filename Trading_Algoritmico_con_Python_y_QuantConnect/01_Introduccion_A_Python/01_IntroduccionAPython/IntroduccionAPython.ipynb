# %%
x = 3

# %%
x
# Out:
# 3

# %% [markdown]
# "=" en programación significa "asignado a"

# %%
y = 10

# %%
Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_30415/2821689564.py in <cell line: 0>()
# ----> 1 Y
#
# NameError: name 'Y' is not defined

# %%
y
# Out:
# 10

# %% [markdown]
# Python es case sensitive y reconoce entre mayúsculas y minúsculas

# %%
a,b = 4,5

# %%
a
# Out:
# 4

# %%
b
# Out:
# 5

# %%
print(a)
# Out:
# 4

# %%
a,b = 6,7,8
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_30415/2383880333.py in <cell line: 0>()
# ----> 1 a,b = 6,7,8
#
# ValueError: too many values to unpack (expected 2)
