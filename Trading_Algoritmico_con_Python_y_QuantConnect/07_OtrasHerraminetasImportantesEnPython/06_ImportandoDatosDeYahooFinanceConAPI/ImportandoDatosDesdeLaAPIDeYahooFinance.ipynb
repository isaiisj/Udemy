# %% [markdown]
# # Importando Datos desde la API de Yahoo Finance Corregido Septiembre 2023

# %%
# Instalamos yfinance

# %%
#!pip install yfinance

# %%
# Importamos yfinance

# %%
import yfinance as yf

# %%
# Importa el módulo 'data' de la biblioteca pandas_datareader y lo renombra como 'pdr'

# %%
from pandas_datareader import data as pdr

# %%
# Habilita el override de Yahoo Finance en el módulo pandas_datareader. En programación y computación, 
# "override" se refiere a reemplazar o modificar una funcionalidad existente. En el caso de yf.pdr_override(), 
# se está modificando el comportamiento predeterminado del módulo pandas_datareader para que utilice Yahoo Finance 
# como fuente de datos.

# %%
yf.pdr_override()

# %%
# Define una lista de tickers que se utilizarán, incluyendo el de Netflix ('NFLX') y el índice NASDAQ Composite ('^IXIC').

# %%
tickers = ['NFLX', '^IXIC', 'TSLA']

# %%
# Importa el módulo 'datetime' de la biblioteca estándar de Python para manejar fechas y horas.

# %%
from datetime import datetime

# %%
# Define las variables 'inicio' y 'fin' con fechas específicas usando el módulo 'datetime'. 
# 'Inicio' se configura para el 26 de septiembre de 2018 y 'fin' para el 26 de septiembre de 2023.

# %%
inicio = datetime(2018, 9, 26)
fin = datetime(2023, 9, 26)

# %%
# Utiliza la función 'get_data_yahoo' del módulo 'pdr' para obtener datos de los 
# tickers especificados entre las fechas 'inicio' y 'fin'.

# %%
datos = pdr.get_data_yahoo(tickers, inicio, fin)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
datos
# Out:
#              Adj Close                                 Close              \
#                   NFLX        TSLA         ^IXIC        NFLX        TSLA
# Date
# 2018-09-26  377.880005   20.638666   7990.370117  377.880005   20.638666
# 2018-09-27  380.709991   20.501333   8041.970215  380.709991   20.501333
# 2018-09-28  374.130005   17.651333   8046.350098  374.130005   17.651333
# 2018-10-01  381.429993   20.713333   8037.299805  381.429993   20.713333
# 2018-10-02  377.140015   20.068001   7999.549805  377.140015   20.068001
# ...                ...         ...           ...         ...         ...
# 2023-09-19  396.200012  266.500000  13678.190430  396.200012  266.500000
# 2023-09-20  386.299988  262.589996  13469.129883  386.299988  262.589996
# 2023-09-21  384.149994  255.699997  13223.980469  384.149994  255.699997
# 2023-09-22  379.809998  244.880005  13211.809570  379.809998  244.880005
# 2023-09-25  384.799988  246.990005  13271.320312  384.799988  246.990005
#
#                                 High                                   Low  \
#                    ^IXIC        NFLX        TSLA         ^IXIC        NFLX
# Date
# 2018-09-26   7990.370117  382.000000   20.926001   8067.029785  370.880005
# 2018-09-27   8041.970215  383.200012   20.997334   8071.560059  376.000000
# 2018-09-28   8046.350098  380.799988   18.533333   8065.060059  373.730011
# 2018-10-01   8037.299805  386.109985   20.762667   8107.379883  375.589996
# 2018-10-02   7999.549805  386.799988   21.122667   8054.149902  373.829987
# ...                  ...         ...         ...           ...         ...
# 2023-09-19  13678.190430  398.230011  267.850006  13705.150391  390.250000
# 2023-09-20  13469.129883  397.989990  273.929993  13727.809570  386.119995
# 2023-09-21  13223.980469  395.899994  260.859985  13362.230469  383.420013
# 2023-09-22  13211.809570  386.880005  257.790009  13353.219727  378.359985
# 2023-09-25  13271.320312  386.619995  247.100006  13277.830078  380.809998
#
#                                             Open                            \
#                   TSLA         ^IXIC        NFLX        TSLA         ^IXIC
# Date
# 2018-09-26   20.073999   7982.759766  373.589996   20.127333   8011.680176
# 2018-09-27   20.460667   8017.910156  379.869995   20.860001   8021.220215
# 2018-09-28   17.370667   8015.870117  379.239990   18.017332   8024.500000
# 2018-10-01   20.070000   8019.770020  375.850006   20.384666   8091.500000
# 2018-10-02   19.943333   7983.990234  384.380005   20.930000   8024.470215
# ...                ...           ...         ...         ...           ...
# 2023-09-19  261.200012  13578.870117  392.839996  264.350006  13649.440430
# 2023-09-20  262.459991  13467.280273  397.049988  267.040009  13710.259766
# 2023-09-21  254.210007  13222.559570  386.500000  257.850006  13328.059570
# 2023-09-22  244.479996  13200.639648  385.000000  257.399994  13287.169922
# 2023-09-25  238.309998  13132.000000  382.899994  243.380005  13172.540039
#
#               Volume
#                 NFLX       TSLA       ^IXIC
# Date
# 2018-09-26  13799700  117648000  2342370000
# 2018-09-27   7326200  127636500  2073930000
# 2018-09-28   7114900  504745500  2342120000
# 2018-10-01   8376600  326664000  2299520000
# 2018-10-02   8638700  176152500  2416800000
# ...              ...        ...         ...
# 2023-09-19   4076800  103704000  4453460000
# 2023-09-20   3866600  122514600  4782440000
# 2023-09-21   5547900  119531000  5014890000
# 2023-09-22   3692800  127024300  4302700000
# 2023-09-25   3757300  104636600  4100290000
#
# [1257 rows x 18 columns]
